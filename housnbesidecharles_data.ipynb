# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"

# %%
df=pd.read_csv(url)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#load dataset function
def load_dataset(file_path):
  try:
    df=pd.read_csv(file_path)
    print("data updated successfully")
    return df
  except UnicodeError:
    print("file not found")
  except Exception as e:
    print(e)

# %%
load_dataset("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")
# Out:
# data updated successfully
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
def show_dataset(df):
  print("First five rows")
  display(df.head())

  print("Last five rows")
  display(df.tail())

  print("random samples")
  display(df.sample())

# %%
show_dataset(df)
# Out:
# First five rows
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# Last five rows
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# ...

# %%
def dataset_info(df):
  print("shape")
  display(df.shape)

  print("columns")
  display(df.columns)

  print("data types")
  print(df.dtypes)

  print("info")
  df.info()

# %%
dataset_info(df)
# Out:
# shape
# (506, 14)
# columns
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
# data types
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object
# info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
# ...

# %%
def statistics(df):
    print("numerical columns")
    display(df.describe().T)

    cat_cols = df.select_dtypes(include=['object', 'category']).columns

    if len(cat_cols) > 0:
        print("categorical columns")
        display(df.describe(include=['object', 'category']).T)
    else:
        print("no categorical columns")

# %%
statistics(df)
# Out:
# numerical columns
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# b        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
def missing_values(df):
  missing = df.isnull().sum()
  percentage = (missing/len(df))*100
  report=pd.DataFrame({"missing":missing,"percentage":percentage})
  return report

# %%
missing_values(df)
# Out:
#          missing  percentage
# crim           0         0.0
# zn             0         0.0
# indus          0         0.0
# chas           0         0.0
# nox            0         0.0
# rm             0         0.0
# age            0         0.0
# dis            0         0.0
# rad            0         0.0
# tax            0         0.0
# ptratio        0         0.0
# b              0         0.0
# lstat          0         0.0
# medv           0         0.0

# %%
def remove_duplicates(df):
  print("duplicates before:",df.duplicated().sum())
  df.drop_duplicates(inplace=True)
  print("duplicates After:",df.duplicated().sum())

# %%
remove_duplicates(df)
# Out:
# duplicates before: 0
# duplicates After: 0

# %%
numeric_columns=df.select_dtypes(include=np.number).columns
numeric_columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
def clean_numeric(df):
  for col in numeric_columns:
    df[col].fillna(df[col].median(),inplace= True)
    print("numeric columns cleaned")

# %%
clean_numeric(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3188/4000885186.py in <cell line: 0>()
# ----> 1 clean_numeric(df)
#
# /tmp/ipykernel_3188/769080231.py in clean_numeric(df)
#       1 def clean_numeric(df):
# ----> 2   for col in numeric_columns:
#       3     df[col].fillna(df[col].median(),inplace= True)
#       4     print("numeric columns cleaned")
#
# NameError: name 'numeric_columns' is not defined

# %%
print(df["crim_rate"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crim_rate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3188/2730047852.py in <cell line: 0>()
# ----> 1 print(df["crim_rate"].value_counts())
#
# ...

# %%
df.corr(numeric_only=True)
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
show_dataset(df)
# Out:
# First five rows
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# Last five rows
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# ...

# %% [markdown]
# Vizualization

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='tax',y='crim',alpha=0.7,color='red')
plt.title('tax vs crimerate ')
plt.grid(True)
plt.show()

# %%
crim_medv=df.groupby("crim")["medv"].mean()

# %%
plt.figure(figsize=(8,5))
plt.plot(crim_medv.index,crim_medv.values,color="darkblue")
plt.xlabel("crim")
plt.ylabel("medv")
plt.grid(True)
plt.show()

# %%
b_medv=df.groupby("b")["medv"].mean()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='b', y='medv', alpha=0.5, color='pink')

plt.xlabel('b')
plt.ylabel('medv')
plt.title('b vs House Price (medv)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df["medv"])
plt.xlabel("medv")
plt.title("medv")
plt.grid(True)
plt.show()

# %%
correlation=df.corr(numeric_only=True)
plt.figure(figsize=(8,5))
sns.heatmap(correlation , annot=True)
plt.title("correlation heatmap")
plt.show()

# %% [markdown]
# Kpi's

# %%
def total_crim(data):
  return data['crim'].sum()

# %%
total_crim(df)
# Out:
# np.float64(1828.4429200000004)

# %%
def minimum_demv(data):
  return data['medv'].min()

# %%
minimum_demv(df)
# Out:
# 5.0

# %%
def maximum_demv(data):
  return data['medv'].max()

# %%
maximum_demv(df)
# Out:
# 50.0

# %%
def average_tax(data):
  return data['tax'].mean()

# %%
average_tax(df)
# Out:
# np.float64(408.2371541501976)

# %%
def total_houses(data):
  return data['medv'].count()

# %%
total_houses(df)
# Out:
# np.int64(506)

# %%
def charles_river_ratio(data):
  return data['chas'].value_counts(normalize=True)

# %%
charles_river_ratio(df)
# Out:
# chas
# 0    0.93083
# 1    0.06917
# Name: proportion, dtype: float64

# %%
df['age_tax_ratio']=df['age']/df['ptratio']

# %%
df['crim_tax_ratio']=df['crim']/df['tax']

# %%
df['tax']=df['tax']*0.10

# %%
show_dataset(df)
# Out:
# First five rows
#       crim    zn  indus  chas    nox     rm   age     dis  rad   tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  29.6     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  24.2     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  24.2     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  22.2     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  22.2     18.7
#
#         b  lstat  medv  age_tax_ratio  crim_tax_ratio
# 0  396.90   4.98  24.0       4.261438        0.000021
# 1  396.90   9.14  21.6       4.432584        0.000113
# 2  392.83   4.03  34.7       3.432584        0.000113
# 3  394.63   2.94  33.4       2.449198        0.000146
# 4  396.90   5.33  36.2       2.898396        0.000311
# Last five rows
#         crim   zn  indus  chas    nox     rm   age     dis  rad   tax  \
# ...
